# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from loguru import logger
import numpy as np

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
f=open('demo.log','w')

# %%
logger.add(f,level='INFO')
# Out:
# 1

# %%
for i in set(df["Country"].tolist()):
    if pd.isna(i):
        continue
    else:
        logger.info("{} = {}".format(i,df["Country"].value_counts()[i]))
# Out:
# 2023-06-16 12:09:58.054 | INFO     | __main__:<module>:5 - China = 664
# 2023-06-16 12:09:58.069 | INFO     | __main__:<module>:5 - Sudan = 42
# 2023-06-16 12:09:58.071 | INFO     | __main__:<module>:5 - Congo, Republic of the... = 7
# 2023-06-16 12:09:58.086 | INFO     | __main__:<module>:5 - Ethiopia = 52
# 2023-06-16 12:09:58.094 | INFO     | __main__:<module>:5 - Czech Republic = 764
# 2023-06-16 12:09:58.103 | INFO     | __main__:<module>:5 - Malaysia = 299
# 2023-06-16 12:09:58.105 | INFO     | __main__:<module>:5 - Cameroon = 51
# 2023-06-16 12:09:58.119 | INFO     | __main__:<module>:5 - Lesotho = 3
# 2023-06-16 12:09:58.121 | INFO     | __main__:<module>:5 - India = 9061
# 2023-06-16 12:09:58.137 | INFO     | __main__:<module>:5 - Bosnia and Herzegovina = 108
# 2023-06-16 12:09:58.138 | INFO     | __main__:<module>:5 - Paraguay = 52
# 2023-06-16 12:09:58.153 | INFO     | __main__:<module>:5 - New Zealand = 524
# ...

# %%
#set(df['Age1stCode'].replace(['Older than 85','Younger than 5 years',nan], [86,4,0]).tolist())
count = 0
c = 0
for i in df["Age1stCode"].tolist():
    #print(i)
    if pd.isna(i) or i=='Older than 85' or i=='Younger than 5 years':
        continue
    else:
        count+=int(i)
        c+=1
print(count//c)
# Out:
# 15

# %%
df["Age1stCode"].value_counts()
# Out:
# 15                      8681
# 16                      8633
# 14                      8452
# 18                      7945
# 12                      7735
# 13                      6377
# 17                      5915
# 10                      5061
# 19                      4561
# 20                      3718
# 11                      3515
# 8                       2471
# 21                      1940
# 9                       1926
# 22                      1710
# 7                       1395
# 23                      1054
# 25                       914
# 24                       842
# 6                        828
# 5                        521
# Younger than 5 years     520
# 26                       491
# 27                       417
# 30                       384
# 28                       346
# 29                       242
# 32                       139
# 35                       134
# 31                       130
# 33                       126
# 34                        92
# ...

# %%
f.close()

# %%
f=open('questions.txt','r')

# %%
lst=list(f)

# %%
for i in lst:
    print(i)
# Out:
# w.r.t  :: "with respect to"
#
#
#
# ..What is the average age at which 1st code was written?
#
#   Ans. 15
#
# ..What is the most common answers in columns 45:54?
#
#    Ans. {
#
#   DBworked_with:(MySQL, PostgreSQL), want_to_work_withDB:(PostgreSQL, MySQL),
#
#   Platform_worked_with:(Linux, Microsoft), Platform_want_to_work_with:(Linux, Docker),
#
#   Web_framework_worked_with:(jQuery, React.js), Web_framework_want_to_work_with:(React.js, Vue.js, Angular/Angular.js )
#
#   MiscTechWorkedWith:(Node.js, .NET), MiscTechDesireNextYear:(Node.js, TensorFlow)
#
#   DevEnv:(Visual Studio Code), OS:(Windows)
#
#             }
#
# ..Construct a graph; no:of people who have a SOaccount at that age vs Age.
#
# ..What is the most common answers in columns 45:54 w.r.t the OS used?
#
# ..Visualize JobSat, WorkWeekHrs, Age and Country.
#
# ..Visualize Age1stCode, Country and JobSat.
#
# ..Which is the country with most satisfied people(could visualize JobSat, Country and WorkWeekHrs)?
#
# ...

# %%
f.close()

# %%
df.iloc[:,[45]].value_counts()
# Out:
# DatabaseWorkedWith
# MySQL                                                                                              5556
# Microsoft SQL Server                                                                               5164
# PostgreSQL                                                                                         2614
# SQLite                                                                                             2027
# Microsoft SQL Server;MySQL                                                                         1868
#                                                                                                    ...
# Couchbase;DynamoDB;Firebase;MariaDB;MongoDB;Microsoft SQL Server;MySQL;Oracle;PostgreSQL;SQLite       1
# Couchbase;DynamoDB;Firebase;MariaDB;MongoDB;MySQL                                                     1
# Elasticsearch;Firebase;MariaDB;MySQL;Redis;Other(s):                                                  1
# ...

# %%
df.iloc[:,[46]].value_counts()
# Out:
# DatabaseDesireNextYear
# PostgreSQL                                                        3539
# Microsoft SQL Server                                              3290
# MySQL                                                             3184
# MongoDB                                                           2250
# SQLite                                                            1506
#                                                                   ...
# Cassandra;Firebase;MariaDB;MongoDB;MySQL;Redis                       1
# DynamoDB;Firebase;MongoDB;MySQL;Oracle;Redis;SQLite                  1
# DynamoDB;Firebase;MongoDB;MySQL;Oracle;PostgreSQL;Redis;SQLite       1
# DynamoDB;Firebase;MongoDB;MySQL;Oracle;PostgreSQL;Redis              1
# Couchbase;MySQL;Oracle                                               1
# Length: 3923, dtype: int64

# %%
df.iloc[:,[47]].value_counts()
# Out:
# PlatformWorkedWith
# Windows                                                                    7031
# Linux;Windows                                                              3329
# Linux                                                                      3298
# Android                                                                    1961
# Microsoft Azure;Windows                                                    1198
#                                                                            ...
# Android;Arduino;Docker;Google Cloud Platform;Raspberry Pi;Slack;Windows       1
# Android;Arduino;Docker;Google Cloud Platform;Raspberry Pi                     1
# Android;Arduino;Docker;Google Cloud Platform;Microsoft Azure;WordPress        1
# Android;Arduino;Docker;Google Cloud Platform;Microsoft Azure;Windows          1
# iOS;WordPress;Other(s):                                                       1
# Length: 8731, dtype: int64

# %%
df.iloc[:,[48]].value_counts()
# Out:
# PlatformDesireNextYear
# Linux                                                                    3280
# Windows                                                                  2967
# Linux;Windows                                                            1696
# Android                                                                  1509
# Docker;Linux                                                             1100
#                                                                          ...
# Android;Arduino;AWS;IBM Cloud or Watson;Microsoft Azure;Slack               1
# Android;Arduino;AWS;IBM Cloud or Watson;Linux;Slack;Windows;WordPress       1
# Android;Arduino;AWS;IBM Cloud or Watson;Linux;Raspberry Pi;WordPress        1
# Android;Arduino;AWS;IBM Cloud or Watson;Linux;Raspberry Pi                  1
# Android;Arduino;Google Cloud Platform;Microsoft Azure;Raspberry Pi          1
# Length: 10795, dtype: int64

# %%
df.iloc[:,[49]].value_counts()
# Out:
# WebFrameWorkedWith
# jQuery                                                                   4171
# ASP.NET;jQuery                                                           2963
# ASP.NET                                                                  2921
# React.js                                                                 2353
# Spring                                                                   2224
#                                                                          ...
# Django;Express;jQuery;Laravel;Spring;Vue.js;Other(s):                       1
# Angular/Angular.js;Django;Drupal;Spring                                     1
# Django;Express;jQuery;Other(s):                                             1
# Angular/Angular.js;Django;Drupal;Ruby on Rails                              1
# Angular/Angular.js;Drupal;Flask;jQuery;Laravel;React.js;Spring;Vue.js       1
# Length: 2142, dtype: int64

# %%
df.iloc[:,[50]].value_counts()
# Out:
# WebFrameDesireNextYear
# React.js                                                    3744
# ASP.NET                                                     2107
# Spring                                                      1705
# Vue.js                                                      1682
# jQuery                                                      1676
#                                                             ...
# Django;Drupal;Laravel;Other(s):                                1
# Django;Drupal;Laravel;React.js;Ruby on Rails;Vue.js            1
# Django;Drupal;Laravel;React.js;Vue.js;Other(s):                1
# Django;Drupal;Laravel;Ruby on Rails                            1
# Angular/Angular.js;ASP.NET;Express;jQuery;Laravel;Spring       1
# Length: 2312, dtype: int64

# %%
df.iloc[:,[51]].value_counts()
# Out:
# MiscTechWorkedWith
# Node.js                                                                             10571
# .NET                                                                                 5006
# .NET;.NET Core                                                                       4513
# .NET;.NET Core;Node.js                                                               2291
# Node.js;React Native                                                                 1696
#                                                                                     ...
# Apache Spark;Flutter;Hadoop;Node.js;Pandas;TensorFlow;Torch/PyTorch                     1
# Apache Spark;Flutter;Hadoop;Node.js;Pandas;React Native;Unity 3D;Unreal Engine          1
# Apache Spark;Flutter;Hadoop;Node.js;Pandas;React Native;Unity 3D                        1
# Apache Spark;Flutter;Hadoop;Node.js;Pandas;React Native;TensorFlow;Torch/PyTorch        1
# ...

# %%
df.iloc[:,[52]].value_counts()
# Out:
# MiscTechDesireNextYear
# Node.js                                                              6913
# .NET;.NET Core                                                       2804
# Node.js;React Native                                                 2570
# TensorFlow                                                           1474
# .NET                                                                 1422
#                                                                      ...
# Chef;.NET Core;Node.js;Unreal Engine                                    1
# Chef;.NET Core;Node.js;Xamarin                                          1
# Ansible;Chef;Hadoop;.NET Core;Node.js;React Native;TensorFlow           1
# Chef;.NET Core;Pandas                                                   1
# Apache Spark;Flutter;Pandas;React Native;TensorFlow;Torch/PyTorch       1
# Length: 5565, dtype: int64

# %%
df.iloc[:,[53]].value_counts()
# Out:
# DevEnviron
# Visual Studio Code                                                                             5036
# Visual Studio;Visual Studio Code                                                               3840
# Notepad++;Visual Studio;Visual Studio Code                                                     3248
# Vim                                                                                            2224
# Notepad++;Visual Studio                                                                        1968
#                                                                                                ...
# Atom;Eclipse;RStudio;Visual Studio                                                                1
# Atom;Eclipse;RStudio;Vim;Visual Studio;Visual Studio Code;Xcode                                   1
# Atom;Eclipse;RStudio;Vim                                                                          1
# ...

# %%
df.iloc[:,[54]].value_counts()
# Out:
# OpSys
# Windows        41714
# MacOS          23541
# Linux-based    22472
# BSD              124
# dtype: int64

# %%
database=df.iloc[:,[52]]

# %%
database=database.replace(np.nan,'None')

# %%
database.value_counts()['None']
# Out:
# 24372

# %%
database=database.values.tolist()

# %%
Lst=[]
for i in database:
    Lst+=i

# %%
lst=[]
for i in Lst:
    lst+=i.split(';')

# %%
database=pd.Series(lst)

# %%
database.value_counts()
# Out:
# Node.js          31417
# None             24372
# TensorFlow       17904
# .NET Core        17077
# .NET             15833
# React Native     14601
# Unity 3D         11131
# Pandas            8885
# Flutter           7307
# Apache Spark      6647
# Ansible           6480
# Unreal Engine     6387
# Torch/PyTorch     6382
# Hadoop            6261
# Xamarin           6001
# Other(s):         3040
# Cordova           2981
# Puppet            2217
# Chef              2154
# CryEngine         1179
# dtype: int64

# %%
df.loc[(df['OpSys']=='Windows') & (df['Country']=='India')].shape
# Out:
# (4566, 85)

# %%
plt.figure(figsize=(14,6))

# %%
database=df['ConvertedComp'].head(20)

# %%
sns.lineplot(data=database)
# Out:
# <Axes: ylabel='ConvertedComp'>

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...
